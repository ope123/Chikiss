# %% [markdown]
# <a href="https://github.com/gutris1/segsmaker">
#   <img alt="GitHub repo" src="https://img.shields.io/badge/GitHub-6e5494?style=for-the-badge&logo=github&logoColor=white"/>
# </a>

# %%
# @title <b><font color='orange'>WebUI Installer</font></b> {"display-mode":"form"}

Webui = 'A1111' # @param ["A1111", "Forge", "ComfyUI", "ReForge", "SwarmUI"]
Civitai___Key = 'f782b1a696f2233407a13d7ef5289d43' # @param { "type": "string", "placeholder": "Your Civitai API key (required)" }
HF_Read_Token = '' # @param {type:"string", placeholder:"Your Huggingface READ token (optional)"}
Mount_GDrive = 'No' # @param ["Yes", "No"]
BGM = '' # @param {type:"string", placeholder:"youtube video id, default to dQw4w9WgXcQ"}

# !curl -sLo /content/setup.py https://github.com/gutris1/segsmaker/raw/main/script/KC/setup.py

if Mount_GDrive == 'Yes':
    from google.colab import drive
    drive.mount('/content/drive')

# %run /content/setup.py --webui="$Webui" --civitai_key="$Civitai___Key" --hf_read_token="$HF_Read_Token" --bgm="$BGM"

from pathlib import Path

if Mount_GDrive == 'Yes':
    d = Path('/content/drive/MyDrive/Segsmaker')

    for n, p in {'checkpoint': CKPT, 'lora': LORA, 'vae': VAE, 'embeddings': Embeddings}.items(): # type: ignore
        f = d / n
        f.mkdir(parents=True, exist_ok=True)
        s = p / f'drive-{n}'
        s.symlink_to(f, target_is_directory=True)

    # !rm -rf $WebUI_Output
    o = d / {'ComfyUI': 'comfyui-output', 'SwarmUI': 'swarmui-output'}.get(Webui, 'output')
    o.mkdir(parents=True, exist_ok=True)
    WebUI_Output.symlink_to(o, target_is_directory=True)
# Out:
# Output()
# Output()

# %%
''' These are placeholders for commands with empty inputs. '''
''' Replace them with actual values or skip/delete this cell. '''


''' SD Extensions / ComfyUI Custom Nodes '''
# %cd -q $Extensions
# !git clone https://github.com/ope123/ope123-additional-networks

''' VAE '''
# %cd -q $VAE
# %download

''' Embeddings '''
# %cd -q $Embeddings
# %download

''' Upscalers '''
# %cd -q $Upscalers
# %download

''' FLUX Unet '''
# %cd -q $UNET
# %download

''' FLUX Clip '''
# %cd -q $CLIP
# %download
# Out:
# Cloning into 'ope123-additional-networks'...
# remote: Enumerating objects: 718, done.
# remote: Counting objects: 100% (372/372), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 718 (delta 299), reused 251 (delta 251), pack-reused 346 (from 1)
# Receiving objects: 100% (718/718), 205.18 KiB | 1.08 MiB/s, done.
# Resolving deltas: 100% (392/392), done.
#   missing URL, downloading nothing
#   missing URL, downloading nothing
#   missing URL, downloading nothing
# [Errno 2] No such file or directory: 'None'
#   missing URL, downloading nothing
# [Errno 2] No such file or directory: 'None'
#   missing URL, downloading nothing

# %%
''' Checkpoint '''
# %cd -q $CKPT
# %download https://huggingface.co/ope123/tang/blob/main/linsu.safetensors

''' LoRA '''
# %cd -q $LORA
# %download https://civitai.com/models/122359/detail-tweaker-xl
# %download https://civitai.com/models/669571/pony-add-more-details
# Out:
#  【#772e8d 3.8GiB/3.9GiB(96%) CN:16 DL:153MiB】
#   772e8d|OK  |   176MiB/s|/content/A1111/models/Stable-diffusion/linsu.safetensors
#  【#9c4a28 80MiB/217MiB(37%) CN:16 DL:172MiB】
#   9c4a28|OK  |   218MiB/s|/content/A1111/models/Lora/add-detail-xl.safetensors
#  【#b8801e 159MiB/217MiB(73%) CN:16 DL:198MiB】
#   b8801e|OK  |   201MiB/s|/content/A1111/models/Lora/Add_more_details_pony.safetensors

# %%
''' Controlnet '''
# %run $Controlnet_Widget
# Out:
# <style>:root {
#   --cn-gradient-bg: linear-gradient(to right,
#     rgb(255, 0, 0), rgb(255, 0, 25), rgb(255, 0, 50), rgb(255, 0, 75),
#     rgb(255, 0, 100), rgb(255, 0, 125), rgb(255, 0, 150), rgb(255, 0, 175),
#     rgb(255, 0, 200), rgb(255, 0, 225), rgb(255, 0, 255), rgb(225, 0, 255),
#     rgb(200, 0, 255), rgb(175, 0, 255), rgb(150, 0, 255), rgb(125, 0, 255),
#     rgb(100, 0, 255), rgb(75, 0, 255), rgb(50, 0, 255), rgb(25, 0, 255),
#     rgb(0, 0, 255), rgb(0, 25, 255), rgb(0, 50, 255), rgb(0, 75, 255),
#     rgb(0, 100, 255), rgb(0, 125, 255), rgb(0, 150, 255), rgb(0, 175, 255),
#     rgb(0, 200, 255), rgb(0, 225, 255), rgb(0, 255, 255), rgb(0, 255, 225),
#     rgb(0, 255, 200), rgb(0, 255, 175), rgb(0, 255, 150), rgb(0, 255, 125),
#     rgb(0, 255, 100), rgb(0, 255, 75), rgb(0, 255, 50), rgb(0, 255, 25),
#     rgb(0, 255, 0), rgb(25, 255, 0), rgb(50, 255, 0), rgb(75, 255, 0),
#     rgb(100, 255, 0), rgb(125, 255, 0), rgb(150, 255, 0), rgb(175, 255, 0),
#     rgb(200, 255, 0), rgb(225, 255, 0), rgb(255, 255, 0), rgb(255, 225, 0),
#     rgb(255, 200, 0), rgb(255, 175, 0), rgb(255, 150, 0), rgb(255, 125, 0),
#     rgb(255, 100, 0), rgb(255, 75, 0), rgb(255, 50, 0), rgb(255, 25, 0),
#     rgb(255, 0, 0));
# }
#
# .cn-panel {
#   border: 0px solid transparent;
#   border-radius: 30px;
#   margin: 0;
#   background-color: transparent;
#   animation: slide-blur-panel 1s;
#   overflow: visible !important;
# }
#
# @keyframes slide-blur-panel {
#   from {
#     height: 0px;
#     opacity: 0;
#     filter: blur(30px);
#   }
#   to {
#     height: 405px;
#     opacity: 1;
#     filter: blur(0px);
#   }
# }
#
# .btn-cn-15, .btn-cn-xl {
#   height: auto;
#   cursor: pointer;
#   border-width: 0px;
#   filter: brightness(50%) blur(5px);
#   background-size: cover;
#   background-position: center;
#   background-repeat: no-repeat;
#   border-radius: 3px;
#   position: relative;
#   overflow: hidden;
#   -webkit-mask: linear-gradient(to left, transparent, #000 1px);
#   width: 70%;
#   box-shadow: inset 0 0 10px 7px #000 !important;
#   transition: 0.4s ease;
# }
#
# .btn-cn-15 {
#   background-image: url('https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/5f06d0e2-5959-4c31-be80-546735970d76/original=true,quality=90/00014-1506.jpeg');
# }
#
# .btn-cn-xl {
#   background-image: url('https://i.imgur.com/giAg91c.jpg');
# }
#
# .btn-cn-15::after, .btn-cn-xl::after {
#   font-family: 'Times New Roman', serif;
#   text-align: center;
#   position: absolute;
#   bottom: 0px;
#   left: -10px;
#   color: white;
#   font-size: 40px;
#   background-color: rgba(0, 0, 0, 0.7);
#   padding: 10px;
#   display: block;
#   border-radius: 0px;
#   width: 100%;
#   filter: drop-shadow(0 0 10px #000);
#   box-shadow: 0 0 10px 1px #000;
# }
#
# .btn-cn-15::after {
#   content: 'SD 1.5';
# }
# .btn-cn-xl::after {
#   content: 'SD XL';
# }
#
# .btn-cn-15:hover, .btn-cn-xl:hover {
#   width: 100%;
#   border-width: 0px;
#   filter: brightness(100%) blur(0);
# }
#
# @keyframes Undress15 {
#   0% {
#     max-height: 0;
#     opacity: 0;
#     filter: blur(10px);
#   }
#   100% {
#     max-height: 490px;
#     opacity: 1;
#     filter: blur(0px);
#   }
# }
#
# @keyframes UndressXL {
#   0% {
#     max-height: 0;
#     opacity: 0;
#     filter: blur(10px);
#   }
#   100% {
#     max-height: 580px;
#     opacity: 1;
#     filter: blur(0px);
#   }
# }
#
# .cn-xl, .cn-15 {
#   position: relative;
#   border: 3px solid transparent;
#   border-radius: 30px;
#   margin: 0;
#   max-height: 0;
#   background-color: transparent;
#   background-size: cover;
#   background-position: center;
# }
#
# .cn-xl {
#   animation: UndressXL 1s forwards ease-out, BorderPulse 15s infinite;
# }
# .cn-15 {
#   animation: Undress15 1s forwards ease-out, BorderPulse 15s infinite;
# }
#
# .cn-xl::before, .cn-15::before {
#   content: '';
#   position: absolute;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   background-image: url('https://i.imgur.com/5Mkdrpw.jpg');
#   background-size: cover;
#   background-position: center;
#   filter: blur(0px);
#   transition: all 0.5s ease;
#   border-radius: 28px;
#   z-index: -1;
#   background-color: rgba(0, 0, 0, 0.5);
#   mix-blend-mode: multiply;
# }
#
# .cn-xl:hover::before, .cn-15:hover::before {
#   filter: blur(10px);
# }
#
# .widget-container {
#   margin: 0;
#   overflow: hidden;
#   position: relative;
# }
#
# .widget-container .checkbox_layout_15,
# .widget-container .checkbox_layout_xl {
#   top: -40px !important;
# }
#
# .widget-container .widget-box {
#   overflow: visible !important;
# }
#
# .cn-xl .download-button-xl,
# .cn-xl .select-all-button-xl,
# .cn-xl .unselect-all-button-xl,
# .cn-15 .download-button-15,
# .cn-15 .select-all-button-15,
# .cn-15 .unselect-all-button-15 {
#   display: flex;
#   outline: none !important;
#   font-weight: bold;
#   position: relative;
#   margin: 0;
#   background-color: transparent;
#   text-align: center;
#   color: cyan;
#   border: 2px solid transparent;
#   border-radius: 100px;
#   height: 40px;
#   font-size: 16px;
#   padding: 0 10px;
#   z-index: 1;
#   justify-content: center;
#   align-items: center;
#   transition: 0.3s ease;
# }
#
# .download-button-15,
# .select-all-button-15,
# .unselect-all-button-15 {
#   top: 415px;
# }
#
# .download-button-xl,
# .select-all-button-xl,
# .unselect-all-button-xl {
#   top: 505px;
# }
#
# .download-button-15,
# .download-button-xl {
#   left: -40px;
#   margin-right: 0px;
#   margin-bottom: 0px;
#   margin-left: 0px;
# }
#
# .select-all-button-15,
# .select-all-button-xl {
#   margin-right: 0px;
#   margin-bottom: 0px;
#   margin-left: 0px;
# }
#
# .unselect-all-button-15,
# .unselect-all-button-xl {
#   left: -40px;
#   margin-right: 0px;
#   margin-bottom: 0px;
#   margin-left: 0px;
# }
#
# .download-button-15:hover,
# .select-all-button-15:hover,
# .unselect-all-button-15:hover,
# .download-button-xl:hover,
# .select-all-button-xl:hover,
# .unselect-all-button-xl:hover {
#   border-color: cyan;
#   filter: drop-shadow(0 0 10px #275EFE);
#   box-shadow: 0 0 10px 1px cyan !important;
#   background-color: cyan;
#   color: #000;
# }
#
# .bottom-box-15, .bottom-box-xl {
#   display: block;
#   user-select: none;
#   -webkit-user-select: none;
#   position: absolute;
#   pointer-events: none;
#   transform: translateX(-50%);
#   height: 55px;
#   border: 3px solid transparent;
#   border-radius: 30px;
#   background-color: rgba(0, 0, 0, 0.9);
#   padding: 0px;
#   animation: BorderPulse 15s infinite;
# }
#
# .bottom-box-15 {
#   bottom: -425px;
#   left: 49.5%;
#   width: 530px;
# }
#
# .bottom-box-xl {
#   bottom: -515px;
#   left: 49.5%;
#   width: 600px;
# }
#
# .checkbox input {
#   --active: #275EFE;
#   --active-inner: #fff;
#   --focus: 2px rgba(39, 94, 254, .3);
#   --border: #BBC1E1;
#   --border-hover: #275EFE;
#   --background: #fff;
#   --disabled: #F6F8FF;
#   --disabled-inner: #E1E6F9;
#   -webkit-appearance: none;
#   -moz-appearance: none;
#   width: 15px;
#   height: 15px;
#   right: 0px;
#   border-radius: 0;
#   margin-top: -3px !important;
#   margin-right: 10px !important;
#   margin-bottom: 0 !important;
#   margin-left: 0 !important;
#   vertical-align: middle;
#   cursor: pointer;
#   border: 0;
#   background-color: rgba(0, 0, 0, 0.5);
#   transition: background-color 0.3s ease, filter 0.3s ease, box-shadow 0.3s ease;
#   position: relative;
#   transform: rotate(45deg);
# }
#
# .checkbox input:checked {
#   border-color: #275EFE;
#   background-color: #275EFE;
#   background-image: radial-gradient(circle, white 30%, transparent 40%);
#   filter: drop-shadow(0 0 10px #275EFE);
#   box-shadow: 0 0 1px 1px #000, 0 0 10px 1px #275EFE;
# }
#
# .checkbox input:checked:hover {
#   background-color: cyan;
#   filter: drop-shadow(0 0 10px cyan);
#   box-shadow: 0 0 10px 1px cyan;
# }
#
# .checkbox input:not(:checked):hover {
#   border-color: #275EFE;
#   background-image: none;
#   filter: drop-shadow(0 0 10px #275EFE);
#   box-shadow: 0 0 10px 1px #275EFE;
# }
#
# .checkbox label {
#   overflow: visible;
#   position: absolute;
#   text-align: left;
#   font-family: 'Roboto Mono', monospace;
#   font-size: 12px;
#   font-weight: bold;
#   color: black;
#   vertical-align: middle;
#   width: max-content;
#   margin: 0;
#   padding: 0 15px;
#   margin-left: -5px;
#   border: 2px solid transparent;
# }
#
# .checkbox label:hover {
#   border-radius: 1rem;
#   color: cyan;
#   background-color: rgba(0, 0, 0, 0.6);
#   border: 2px solid rgba(0, 0, 0, 0.6);
#   cursor: pointer;
#   filter: drop-shadow(0 0 10px cyan);
#   box-shadow: 0 0 3px 0 cyan;
#   animation: BorderPulse 7s infinite;
# }
#
# @keyframes s
# HBox(children=(Button(style=ButtonStyle(), _dom_classes=('btn-cn-15',)), Button(style=ButtonStyle(), _dom_clas…
# Box(children=(HBox(children=(Button(description='Select All', layout=Layout(left='15px', width='130px'), style…
# Box(children=(HBox(children=(Button(description='Select All', layout=Layout(left='30px'), style=ButtonStyle(),…
# Output()

# %% [markdown]
# ## Launcher
# args list :
# -  **A1111** = `--xformers`
# - **Forge** = `--disable-xformers --opt-sdp-attention --cuda-stream --pin-shared-memory`
# - **ComfyUI** = `--dont-print-server --preview-method auto --use-pytorch-cross-attention`
# - **ReForge** = `--xformers --cuda-stream --pin-shared-memory`
# - **SwarmUI** = `--launch_mode none`
# <br><br>
#
# For ComfyUI, add `--skip-comfyui-check` to skip checking the main requirements and custom node dependencies
#
# Add **--N=ngrok_token** to start NGROK tunnel<br>
# Add **--Z=zrok_token** to start ZROK tunnel

# %%
# %cd -q $WebUI
# %run segsmaker.py --xformers
# Out:
# Python 3.10.15 (main, Oct 16 2024, 04:37:23) [Clang 18.1.8 ]
# Version: v1.10.1
# Commit hash: 82a973c04367123ae98bd9abdf80d9eda9b910e2
# Installing None
# Launching Web UI with arguments: --xformers --enable-insecure-extension-access --disable-console-progressbars --theme dark --share
# [-] ADetailer initialized. version: 25.3.0, num models: 10
# Tag Autocomplete: Could not locate model-keyword extension, Lora trigger word completion will be limited to those added through the extra networks menu.
# [AddNet] Updating model hashes...
# 100% 1/1 [00:00<00:00, 1661.11it/s]
# [AddNet] Updating model hashes...
# 100% 1/1 [00:00<00:00, 1626.96it/s]
# CivitAI Browser+: Aria2 RPC started
# ▶ SD-Hub: v9.0.0
# ControlNet preprocessor location: /content/A1111/extensions/sd-webui-controlnet/annotator/downloads
# 2025-04-28 09:08:15,208 - ControlNet - INFO - ControlNet v1.1.455
# Loading weights [fc2511737a] from /content/A1111/models/Stable-diffusion/linsu.safetensors
# 2025-04-28 09:08:16,634 - ControlNet - INFO - ControlNet UI callback registered.
# Creating model from config: /content/A1111/configs/v1-inference.yaml
# /content/A1111/extensions/ope123-additional-networks/scripts/metadata_editor.py:399: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   with gr.Row().style(equal_height=False):
# /content/A1111/extensions/ope123-additional-networks/scripts/metadata_editor.py:521: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   cover_image = gr.Image(
# [ERROR]: Config states /content/A1111/config_states/civitai_subfolders.json, "created_at" does not exist
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://fe6f5f1fd1ba07de12.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# IIB Database file has been successfully backed up to the backup folder.
# Startup time: 38.3s (prepare environment: 18.4s, import torch: 7.3s, import gradio: 2.1s, setup paths: 1.3s, initialize shared: 0.2s, other imports: 0.5s, load scripts: 3.7s, create ui: 2.5s, gradio launch: 1.2s, app_started_callback: 1.0s).
#
# 🟢 Pinggy : https://rnobf-34-125-85-9.a.free.pinggy.link
#
# 🟢 Cloudflared : http://shows-affair-considering-violations.trycloudflare.com
#
# Applying attention optimization: xformers... done.
# Model loaded in 9.7s (load weights from disk: 1.3s, create model: 0.8s, apply weights to model: 6.7s, apply half(): 0.1s, load textual inversion embeddings: 0.2s, calculate empty prompt: 0.3s).
# CivitAI Browser+: model: "EyeDetail.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "HairDetail.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "HandNeg-neg.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "HyperStylizeV6.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "SkinDetail.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "SkinDetailNeg-neg.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "SkinHairDetail.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "bad_prompt.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "fFaceDetail .pt" not found on CivitAI servers.
# CivitAI Browser+: model: "fHandDetail.pt" not found on CivitAI servers.
# CivitAI Browser+: model: "4x-AnimeSharp.pth" not found on CivitAI servers.
# CivitAI Browser+: model: "4x_NMKD-UltraYandere_300k.pth" not found on CivitAI servers.
# CivitAI Browser+: model: "4x_NMKD-YandereNeoXL_200k.pth" not found on CivitAI servers.
# CivitAI Browser+: model: "8x_RealESRGAN.pth" not found on CivitAI servers.
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/7dirtywords.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/AissistXLv2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/AloeAntiCGI-1500-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/AloeCrapArt-1000-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/AloeDeBokeh-1500-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/AloeRealityNeg-1500-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/AloeRealityNeg2-8000-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/AmoreNegative-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Asian-Less-Neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Asian-Less-Toon.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Asian-Less.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Asian-Less2-Neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/BadDream.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/BadNegAnatomyV1-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Beyondv4-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Concordant-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/CyberRealistic_Negative-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/EarthAnimix-Neg-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/EasyNegativeV2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Ellis-RealismBoost-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/EllisMix-AntiNSFW-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/EllisMix-Neg-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/EllisMix-NoPornPls-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/EpicMix-AntiDoll-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/EpicMix-AntiLady.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/FastNegative.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/FastNegativeEmbedding.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/FastNegativeV2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/ImgFixerPre0.3.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/JuggernautNegative-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/KNXO.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/NaturallyCoolDetailer_NegV1.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Neg-Quality-HoseDown.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Neg512-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/NegFixBadPhoto-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/NegativeDynamics-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/NegativeFusion.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/NegativeFusion_Anime-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/NegfeetV2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/No512-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Portrait512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/PunchIt_NegV1.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/Realisian-Neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/SLPASHTER_3-7000.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/SUperNEgaTiveTester2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/SimpleNegative.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/SimpleNegativeV2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/SimplePositiveXLv2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/SuperNeg-Test.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/TooSkinny-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/UnrealisticDream.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/advntr.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/an14.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/an9.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/anime-style-negative-embedding.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/anime512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/antiBlurV2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/antiSketchV2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/atompunkstylesd15.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/awful512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/bad-hands-5.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/bad-image-v2-39000-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/bad-picture-chill-75v.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/bad_pictures.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/badhandv4.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/beauty512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/bhands-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/boring_e621_v4.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/charturnerv2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/corneo_covering_breasts_two_hands.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/corneo_x_pasties.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/edgQuality.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/epiCNegative.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/epiCRealism.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/flower_style.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/galaxybad_embedding.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/ghst-3000.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/gnarlysick-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/handmade2d.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/hoppagames.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/kkw-Extreme-Neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/magicalinterior.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/myself-badhand-v49.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/neg_anime512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/neg_facelift512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/neg_grapefruit.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/neg_hands512-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/neg_realism512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/negative_hand-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/negativeembed.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/ng_deepnegative_v1_64t.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/ng_deepnegative_v1_75t.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/nothistyles-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/notoon-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/np_simple_negatives.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/np_simple_negatives_v2.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/olfn.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/pureerosface_v1.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/realisticvision-negative-embedding.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/render512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/rfneg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/rmadanegative402_sd15-neg.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/rz-neg-15-foranalog.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/selfie512.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/southofthebordersd15.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/space_style.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/strong_negative.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/style-paintmagic.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/style-rustmagic.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/style-swirlmagic.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/style-sylvamagic.json"
# CivitAI Browser+: Model info saved to "/content/A1111/embeddings/verybadimagenegative_v1.3.json"
# CivitAI Browser+: Model info saved to "/content/A1111/models/Lora/Add_more_details_pony.json"
# CivitAI Browser+: Model info saved to "/content/A1111/models/Lora/add-detail-xl.json"
# CivitAI Browser+: Model saved to: /content/A1111/models/Lora/yor.safetensors
# CivitAI Browser+: Model info saved to "/content/A1111/models/Lora/yor.json"
# CivitAI Browser+: HTML saved at "/content/A1111/models/Lora/yor.html"
# CivitAI Browser+: Preview saved at "/content/A1111/models/Lora/yor.preview.png"
# [AddNet] Updating model hashes...
# 100% 1/1 [00:00<00:00, 1866.62it/s]
# CivitAI Browser+: Model moved to trash based on SHA-256: /content/A1111/models/Lora/yor.json
# CivitAI Browser+: Associated file moved to trash: /content/A1111/models/Lora/yor.html
# CivitAI Browser+: Associated file moved to trash: /content/A1111/models/Lora/yor.preview.png
# CivitAI Browser+: Associated file moved to trash: /content/A1111/models/Lora/yor.safetensors
# CivitAI Browser+: Model saved to: /content/A1111/models/Lora/tmp_lora/yor_20102.safetensors
# CivitAI Browser+: Model info saved to "/content/A1111/models/Lora/tmp_lora/yor_20102.json"
# CivitAI Browser+: HTML saved at "/content/A1111/models/Lora/tmp_lora/yor_20102.html"
# CivitAI Browser+: Preview saved at "/content/A1111/models/Lora/tmp_lora/yor_20102.preview.png"
# [AddNet] Updating model hashes...
# 100% 2/2 [00:00<00:00,  4.78it/s]
# LoRA weight_unet: 0.9, weight_tenc: 0.9, model: yor_20102(56b4cf7ffd51)
# dimension: {64}, alpha: {32.0}, multiplier_unet: 0.9, multiplier_tenc: 0.9
# create LoRA for Text Encoder: 72 modules.
# create LoRA for U-Net: 192 modules.
# original forward/weights is backed up.
# enable LoRA for text encoder
# enable LoRA for U-Net
# shapes for 0 weights are converted.
# LoRA model yor_20102(56b4cf7ffd51) loaded: <All keys matched successfully>
# setting (or sd model) changed. new networks created.
# 100% 23/23 [00:20<00:00,  1.15it/s]
# restoring last networks
# original forward/weights is restored.
# LoRA weight_unet: 0.8, weight_tenc: 0.8, model: yor_20102(56b4cf7ffd51)
# dimension: {64}, alpha: {32.0}, multiplier_unet: 0.8, multiplier_tenc: 0.8
# create LoRA for Text Encoder: 72 modules.
# create LoRA for U-Net: 192 modules.
# original forward/weights is backed up.
# enable LoRA for text encoder
# enable LoRA for U-Net
# shapes for 0 weights are converted.
# LoRA model yor_20102(56b4cf7ffd51) loaded: <All keys matched successfully>
# setting (or sd model) changed. new networks created.
# 100% 23/23 [00:20<00:00,  1.14it/s]
# Error parsing "Hires prompt: "
# Error parsing "Hires negative prompt: "
# 100% 23/23 [00:07<00:00,  3.04it/s]
# 100% 23/23 [00:47<00:00,  2.06s/it]
# Interrupted with signal 2 in <frame at 0x78d938000bb0, file '/GUTRIS1/lib/python3.10/threading.py', line 324, code wait>
#
# Pinggy, Cloudflared Died.
